# %% [markdown]
# # Analise

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns
# CSV Import
candidatos_tec1 = pd.read_csv('candidatos_tecnologia_1.csv')
candidatos_tec2 = pd.read_csv('candidatos_tecnologia_2.csv')
candidatos_tec3 = pd.read_csv('candidatos_tecnologia_3.csv')

# %%
candidatos_tec1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_candidato             1000 non-null   int64
#  1   data_inscricao           1000 non-null   object
#  2   nome                     900 non-null    object
#  3   genero                   900 non-null    object
#  4   estado                   900 non-null    object
#  5   idade                    900 non-null    float64
#  6   formacao                 900 non-null    object
#  7   area_atuacao             900 non-null    object
#  8   experiencia_anos         900 non-null    float64
#  9   certificacoes            900 non-null    float64
#  10  idiomas                  900 non-null    object
#  11  pretensao_salarial       900 non-null    float64
#  12  salario_vaga             900 non-null    float64
#  13  disponibilidade_viagem   900 non-null    object
# ...

# %%
candidatos_tec2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   codigo_candidato    1000 non-null   int64
#  1   data_cadastro       1000 non-null   object
#  2   nome_completo       900 non-null    object
#  3   sexo                900 non-null    object
#  4   uf                  900 non-null    object
#  5   faixa_etaria        900 non-null    float64
#  6   nivel_educacional   900 non-null    object
#  7   setor_profissional  900 non-null    object
#  8   tempo_experiencia   900 non-null    float64
#  9   qtd_certificacoes   900 non-null    float64
#  10  idioma_principal    900 non-null    object
#  11  salario_esperado    900 non-null    float64
#  12  salario_oferecido   900 non-null    float64
#  13  aceita_viagem       900 non-null    object
#  14  aceita_mudanca      900 non-null    object
# ...

# %%
candidatos_tec3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID DO CANDIDATO          1000 non-null   int64
#  1   DATA DE INSCRIÇÃO        1000 non-null   object
#  2   NOME COMPLETO            900 non-null    object
#  3   GÊNERO                   900 non-null    object
#  4   ESTADO                   900 non-null    object
#  5   IDADE                    900 non-null    float64
#  6   FORMAÇÃO ACADÊMICA       900 non-null    object
#  7   ÁREA DE ATUAÇÃO          900 non-null    object
#  8   ANOS DE EXPERIÊNCIA      900 non-null    float64
#  9   CERTIFICAÇÕES            900 non-null    float64
#  10  IDIOMA                   900 non-null    object
#  11  PRETENSÃO SALARIAL       900 non-null    float64
#  12  SALÁRIO DA VAGA          900 non-null    float64
#  13  DISPONÍVEL PARA VIAGENS  900 non-null    object
# ...

# %%
candidatos_tec1
# Out:
#      id_candidato data_inscricao            nome     genero estado  idade  \
# 0               1     2022-04-13     Candidato_1  Masculino     SP   23.0
# 1               2     2023-03-12     Candidato_2  Masculino     MG    NaN
# 2               3     2022-09-28     Candidato_3  Masculino     DF   61.0
# 3               4     2022-04-17     Candidato_4      Outro     PE   28.0
# 4               5     2022-03-13     Candidato_5      Outro     RS   19.0
# ..            ...            ...             ...        ...    ...    ...
# 995           996     2023-10-04   Candidato_996  Masculino     MG   60.0
# 996           997     2023-08-19   Candidato_997        NaN     CE   56.0
# 997           998     2022-11-17   Candidato_998        NaN     RS   34.0
# 998           999     2022-11-15   Candidato_999   Feminino     PR   37.0
# 999          1000     2023-09-05  Candidato_1000  Masculino     RJ   41.0
#
#          formacao      area_atuacao  experiencia_anos  certificacoes  \
# ...

# %% [markdown]
# # FORMATANDO O NOME DAS SÉRIES DO CSV 1

# %%
candidatos_tec1 = candidatos_tec1.rename(columns={'id_candidato' : 'ID DO CANDIDATO', 'data_inscricao':'DATA DA INSCRIÇÃO', 'nome':'NOME', 'genero': 'SEXO', 'estado': 'UF', 'idade': 'IDADE', 'formacao':'FORMAÇÃO', 'area_atuacao': 'ÀREA DE ATUAÇÃO','experiencia_anos':'EXPERIÊNCIA', 'certificacoes':'CERTIFICAÇÕES', 'idiomas':'IDIOMAS','pretensao_salarial':'PRETENÇÃO SALARIAL', 'salario_vaga':'SALÁRIO DA VAGA', 'disponibilidade_viagem':'DISPONIVEL PARA VIAGEM','disponibilidade_mudanca':'DISPONIBILIDADE DE MUDANÇA','pcd':'PCD','contratado':'CONTRATADO'})
candidatos_tec1
# Out:
#      ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO  UF  IDADE  \
# 0                  1        2022-04-13     Candidato_1  Masculino  SP   23.0
# 1                  2        2023-03-12     Candidato_2  Masculino  MG    NaN
# 2                  3        2022-09-28     Candidato_3  Masculino  DF   61.0
# 3                  4        2022-04-17     Candidato_4      Outro  PE   28.0
# 4                  5        2022-03-13     Candidato_5      Outro  RS   19.0
# ..               ...               ...             ...        ...  ..    ...
# 995              996        2023-10-04   Candidato_996  Masculino  MG   60.0
# 996              997        2023-08-19   Candidato_997        NaN  CE   56.0
# 997              998        2022-11-17   Candidato_998        NaN  RS   34.0
# 998              999        2022-11-15   Candidato_999   Feminino  PR   37.0
# 999             1000        2023-09-05  Candidato_1000  Masculino  RJ   41.0
#
# ...

# %%
candidatos_tec1
# Out:
#      ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO  UF  IDADE  \
# 0                  1        2022-04-13     Candidato_1  Masculino  SP   23.0
# 1                  2        2023-03-12     Candidato_2  Masculino  MG    NaN
# 2                  3        2022-09-28     Candidato_3  Masculino  DF   61.0
# 3                  4        2022-04-17     Candidato_4      Outro  PE   28.0
# 4                  5        2022-03-13     Candidato_5      Outro  RS   19.0
# ..               ...               ...             ...        ...  ..    ...
# 995              996        2023-10-04   Candidato_996  Masculino  MG   60.0
# 996              997        2023-08-19   Candidato_997        NaN  CE   56.0
# 997              998        2022-11-17   Candidato_998        NaN  RS   34.0
# 998              999        2022-11-15   Candidato_999   Feminino  PR   37.0
# 999             1000        2023-09-05  Candidato_1000  Masculino  RJ   41.0
#
# ...

# %% [markdown]
# # FORMATANDO OS NOMES DAS SERIES DO CSV 2

# %%
candidatos_tec2
# Out:
#      codigo_candidato data_cadastro   nome_completo       sexo  uf  \
# 0                   1    2022-04-13     Candidato_1  Masculino  SP
# 1                   2    2023-03-12     Candidato_2  Masculino  MG
# 2                   3    2022-09-28     Candidato_3  Masculino  DF
# 3                   4    2022-04-17     Candidato_4      Outro  PE
# 4                   5    2022-03-13     Candidato_5      Outro  RS
# ..                ...           ...             ...        ...  ..
# 995               996    2023-10-04   Candidato_996  Masculino  MG
# 996               997    2023-08-19   Candidato_997        NaN  CE
# 997               998    2022-11-17   Candidato_998        NaN  RS
# 998               999    2022-11-15   Candidato_999   Feminino  PR
# 999              1000    2023-09-05  Candidato_1000  Masculino  RJ
#
#      faixa_etaria nivel_educacional setor_profissional  tempo_experiencia  \
# 0            23.0          Mestrado         Financeiro                4.8
# ...

# %%
candidatos_tec2 = candidatos_tec2.rename(columns={'codigo_candidato' : 'ID DO CANDIDATO', 'data_cadastro':'DATA DA INSCRIÇÃO', 'nome_completo':'NOME', 'sexo': 'SEXO', 'uf': 'UF', 'faixa_etaria': 'IDADE', 'nivel_educacional':'FORMAÇÃO', 'setor_profissional': 'ÀREA DE ATUAÇÃO','tempo_experiencia':'EXPERIÊNCIA', 'qtd_certificacoes':'CERTIFICAÇÕES', 'idioma_principal':'IDIOMAS','salario_esperado':'PRETENÇÃO SALARIAL', 'salario_oferecido':'SALÁRIO DA VAGA', 'aceita_viagem':'DISPONIVEL PARA VIAGEM','aceita_mudanca':'DISPONIBILIDADE DE MUDANÇA','deficiencia':'PCD','foi_contratado':'CONTRATADO'})
candidatos_tec2
# Out:
#      ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO  UF  IDADE  \
# 0                  1        2022-04-13     Candidato_1  Masculino  SP   23.0
# 1                  2        2023-03-12     Candidato_2  Masculino  MG    NaN
# 2                  3        2022-09-28     Candidato_3  Masculino  DF   61.0
# 3                  4        2022-04-17     Candidato_4      Outro  PE   28.0
# 4                  5        2022-03-13     Candidato_5      Outro  RS   19.0
# ..               ...               ...             ...        ...  ..    ...
# 995              996        2023-10-04   Candidato_996  Masculino  MG   60.0
# 996              997        2023-08-19   Candidato_997        NaN  CE   56.0
# 997              998        2022-11-17   Candidato_998        NaN  RS   34.0
# 998              999        2022-11-15   Candidato_999   Feminino  PR   37.0
# 999             1000        2023-09-05  Candidato_1000  Masculino  RJ   41.0
#
# ...

# %%
# Verificando se a planilha 2 está igual a planilha 1, se der True, está igual.
print(candidatos_tec1.columns.equals(candidatos_tec2.columns))
# Out:
# True

# %% [markdown]
# # Formatando o CSV 3

# %%
candidatos_tec3
# Out:
#      ID DO CANDIDATO DATA DE INSCRIÇÃO   NOME COMPLETO     GÊNERO ESTADO  \
# 0                  1        2022-04-13     Candidato_1  Masculino     SP
# 1                  2        2023-03-12     Candidato_2  Masculino     MG
# 2                  3        2022-09-28     Candidato_3  Masculino     DF
# 3                  4        2022-04-17     Candidato_4      Outro     PE
# 4                  5        2022-03-13     Candidato_5      Outro     RS
# ..               ...               ...             ...        ...    ...
# 995              996        2023-10-04   Candidato_996  Masculino     MG
# 996              997        2023-08-19   Candidato_997        NaN     CE
# 997              998        2022-11-17   Candidato_998        NaN     RS
# 998              999        2022-11-15   Candidato_999   Feminino     PR
# 999             1000        2023-09-05  Candidato_1000  Masculino     RJ
#
#      IDADE FORMAÇÃO ACADÊMICA   ÁREA DE ATUAÇÃO  ANOS DE EXPERIÊNCIA  \
# ...

# %%
candidatos_tec3 = candidatos_tec3.rename(columns={'ID DO CANDIDATO' : 'ID DO CANDIDATO', 'DATA DE INSCRIÇÃO':'DATA DA INSCRIÇÃO', 'NOME COMPLETO':'NOME', 'GÊNERO': 'SEXO', 'ESTADO': 'UF', 'IDADE': 'IDADE', 'FORMAÇÃO ACADÊMICA':'FORMAÇÃO', 'ÁREA DE ATUAÇÃO': 'ÀREA DE ATUAÇÃO','ANOS DE EXPERIÊNCIA':'EXPERIÊNCIA', 'CERTIFICAÇÕES':'CERTIFICAÇÕES', 'IDIOMA':'IDIOMAS','PRETENSÃO SALARIAL':'PRETENÇÃO SALARIAL', 'SALÁRIO DA VAGA':'SALÁRIO DA VAGA', 'DISPONÍVEL PARA VIAGENS':'DISPONIVEL PARA VIAGEM','DISPONÍVEL PARA MUDANÇA':'DISPONIBILIDADE DE MUDANÇA','É PCD':'PCD','STATUS DE CONTRATAÇÃO':'CONTRATADO'})
candidatos_tec3
# Out:
#      ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO  UF  IDADE  \
# 0                  1        2022-04-13     Candidato_1  Masculino  SP   23.0
# 1                  2        2023-03-12     Candidato_2  Masculino  MG    NaN
# 2                  3        2022-09-28     Candidato_3  Masculino  DF   61.0
# 3                  4        2022-04-17     Candidato_4      Outro  PE   28.0
# 4                  5        2022-03-13     Candidato_5      Outro  RS   19.0
# ..               ...               ...             ...        ...  ..    ...
# 995              996        2023-10-04   Candidato_996  Masculino  MG   60.0
# 996              997        2023-08-19   Candidato_997        NaN  CE   56.0
# 997              998        2022-11-17   Candidato_998        NaN  RS   34.0
# 998              999        2022-11-15   Candidato_999   Feminino  PR   37.0
# 999             1000        2023-09-05  Candidato_1000  Masculino  RJ   41.0
#
# ...

# %%
# Verificando se a planilha 3 está igual a planilha 1, se der True, está igual.
print(candidatos_tec1.columns.equals(candidatos_tec3.columns))
# Out:
# True

# %% [markdown]
# # Juntando as 3 bases em uma só.

# %%
candidatos = pd.concat([candidatos_tec1,candidatos_tec2,candidatos_tec3], ignore_index = True)
candidatos
candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID DO CANDIDATO             3000 non-null   int64
#  1   DATA DA INSCRIÇÃO           3000 non-null   object
#  2   NOME                        2700 non-null   object
#  3   SEXO                        2700 non-null   object
#  4   UF                          2700 non-null   object
#  5   IDADE                       2700 non-null   float64
#  6   FORMAÇÃO                    2700 non-null   object
#  7   ÀREA DE ATUAÇÃO             2700 non-null   object
#  8   EXPERIÊNCIA                 2700 non-null   float64
#  9   CERTIFICAÇÕES               2700 non-null   float64
#  10  IDIOMAS                     2700 non-null   object
#  11  PRETENÇÃO SALARIAL          2700 non-null   float64
#  12  SALÁRIO DA VAGA             2700 non-null   float64
# ...

# %% [markdown]
# # Formatando Candidatos.CSV

# %%
# Mudando candidatos-float para object.
candidatos['CONTRATADO'] = candidatos['CONTRATADO'].astype(str)
candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID DO CANDIDATO             3000 non-null   int64
#  1   DATA DA INSCRIÇÃO           3000 non-null   object
#  2   NOME                        2700 non-null   object
#  3   SEXO                        2700 non-null   object
#  4   UF                          2700 non-null   object
#  5   IDADE                       2700 non-null   float64
#  6   FORMAÇÃO                    2700 non-null   object
#  7   ÀREA DE ATUAÇÃO             2700 non-null   object
#  8   EXPERIÊNCIA                 2700 non-null   float64
#  9   CERTIFICAÇÕES               2700 non-null   float64
#  10  IDIOMAS                     2700 non-null   object
#  11  PRETENÇÃO SALARIAL          2700 non-null   float64
#  12  SALÁRIO DA VAGA             2700 non-null   float64
# ...

# %% [markdown]
# # ANALISE
# ## Inspeção Inicial

# %%
# Tipos de dados
candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID DO CANDIDATO             3000 non-null   int64
#  1   DATA DA INSCRIÇÃO           3000 non-null   object
#  2   NOME                        2700 non-null   object
#  3   SEXO                        2700 non-null   object
#  4   UF                          2700 non-null   object
#  5   IDADE                       2700 non-null   float64
#  6   FORMAÇÃO                    2700 non-null   object
#  7   ÀREA DE ATUAÇÃO             2700 non-null   object
#  8   EXPERIÊNCIA                 2700 non-null   float64
#  9   CERTIFICAÇÕES               2700 non-null   float64
#  10  IDIOMAS                     2700 non-null   object
#  11  PRETENÇÃO SALARIAL          2700 non-null   float64
#  12  SALÁRIO DA VAGA             2700 non-null   float64
# ...

# %%
# 10 Linhas iniciais da base
candidatos.head(10)
# Out:
#    ID DO CANDIDATO DATA DA INSCRIÇÃO          NOME       SEXO   UF  IDADE  \
# 0                1        2022-04-13   Candidato_1  Masculino   SP   23.0
# 1                2        2023-03-12   Candidato_2  Masculino   MG    NaN
# 2                3        2022-09-28   Candidato_3  Masculino   DF   61.0
# 3                4        2022-04-17   Candidato_4      Outro   PE   28.0
# 4                5        2022-03-13   Candidato_5      Outro   RS   19.0
# 5                6        2023-12-02   Candidato_6   Feminino   SC    NaN
# 6                7        2022-01-21   Candidato_7        NaN   DF    NaN
# 7                8        2023-09-07   Candidato_8      Outro  NaN   61.0
# 8                9        2022-05-02           NaN   Feminino   SC    NaN
# 9               10        2023-04-12  Candidato_10      Outro  NaN   38.0
#
#        FORMAÇÃO ÀREA DE ATUAÇÃO  EXPERIÊNCIA  CERTIFICAÇÕES   IDIOMAS  \
# 0      Mestrado      Financeiro          4.8            3.0  Espanhol
# ...

# %%
# 10 Linhas finais da Base
candidatos.tail(10)
# Out:
#       ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO   UF  \
# 2990              991        2022-09-18   Candidato_991   Feminino   CE
# 2991              992        2023-10-12   Candidato_992      Outro   RS
# 2992              993        2022-06-21   Candidato_993      Outro   RJ
# 2993              994        2022-01-13             NaN        NaN  NaN
# 2994              995        2022-06-17   Candidato_995   Feminino   BA
# 2995              996        2023-10-04   Candidato_996  Masculino   MG
# 2996              997        2023-08-19   Candidato_997        NaN   CE
# 2997              998        2022-11-17   Candidato_998        NaN   RS
# 2998              999        2022-11-15   Candidato_999   Feminino   PR
# 2999             1000        2023-09-05  Candidato_1000  Masculino   RJ
#
#       IDADE      FORMAÇÃO   ÀREA DE ATUAÇÃO  EXPERIÊNCIA  CERTIFICAÇÕES  \
# 2990   49.0           NaN  Recursos Humanos         -0.8            3.0
# ...

# %%
# Nome das Colunas
candidatos.columns
# Out:
# Index(['ID DO CANDIDATO', 'DATA DA INSCRIÇÃO', 'NOME', 'SEXO', 'UF', 'IDADE',
#        'FORMAÇÃO', 'ÀREA DE ATUAÇÃO', 'EXPERIÊNCIA', 'CERTIFICAÇÕES',
#        'IDIOMAS', 'PRETENÇÃO SALARIAL', 'SALÁRIO DA VAGA',
#        'DISPONIVEL PARA VIAGEM', 'DISPONIBILIDADE DE MUDANÇA', 'PCD',
#        'CONTRATADO'],
#       dtype='object')

# %% [markdown]
# # IDENDIFICANDO DUPLICADAS E EXCLUINDO-AS

# %%
#  Todas as LINHAS duplicadas com base em todas as colunas
candidatos.loc[candidatos.duplicated()]
# Out:
#       ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO  UF  IDADE  \
# 1000                1        2022-04-13     Candidato_1  Masculino  SP   23.0
# 1001                2        2023-03-12     Candidato_2  Masculino  MG    NaN
# 1002                3        2022-09-28     Candidato_3  Masculino  DF   61.0
# 1003                4        2022-04-17     Candidato_4      Outro  PE   28.0
# 1004                5        2022-03-13     Candidato_5      Outro  RS   19.0
# ...               ...               ...             ...        ...  ..    ...
# 2995              996        2023-10-04   Candidato_996  Masculino  MG   60.0
# 2996              997        2023-08-19   Candidato_997        NaN  CE   56.0
# 2997              998        2022-11-17   Candidato_998        NaN  RS   34.0
# 2998              999        2022-11-15   Candidato_999   Feminino  PR   37.0
# 2999             1000        2023-09-05  Candidato_1000  Masculino  RJ   41.0
#
# ...

# %%
# Indices dos Duplicados
indices = candidatos[candidatos.duplicated()].index

# linhas duplicadas pelo iloc
candidatos.iloc[indices]
# Out:
#       ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO  UF  IDADE  \
# 1000                1        2022-04-13     Candidato_1  Masculino  SP   23.0
# 1001                2        2023-03-12     Candidato_2  Masculino  MG    NaN
# 1002                3        2022-09-28     Candidato_3  Masculino  DF   61.0
# 1003                4        2022-04-17     Candidato_4      Outro  PE   28.0
# 1004                5        2022-03-13     Candidato_5      Outro  RS   19.0
# ...               ...               ...             ...        ...  ..    ...
# 2995              996        2023-10-04   Candidato_996  Masculino  MG   60.0
# 2996              997        2023-08-19   Candidato_997        NaN  CE   56.0
# 2997              998        2022-11-17   Candidato_998        NaN  RS   34.0
# 2998              999        2022-11-15   Candidato_999   Feminino  PR   37.0
# 2999             1000        2023-09-05  Candidato_1000  Masculino  RJ   41.0
#
# ...

# %%
# Removendo as duplicadas matendo a primeira
candidatos_limpo = candidatos_tec1.drop_duplicates()

candidatos_limpo
# Out:
#      ID DO CANDIDATO DATA DA INSCRIÇÃO            NOME       SEXO  UF  IDADE  \
# 0                  1        2022-04-13     Candidato_1  Masculino  SP   23.0
# 1                  2        2023-03-12     Candidato_2  Masculino  MG    NaN
# 2                  3        2022-09-28     Candidato_3  Masculino  DF   61.0
# 3                  4        2022-04-17     Candidato_4      Outro  PE   28.0
# 4                  5        2022-03-13     Candidato_5      Outro  RS   19.0
# ..               ...               ...             ...        ...  ..    ...
# 995              996        2023-10-04   Candidato_996  Masculino  MG   60.0
# 996              997        2023-08-19   Candidato_997        NaN  CE   56.0
# 997              998        2022-11-17   Candidato_998        NaN  RS   34.0
# 998              999        2022-11-15   Candidato_999   Feminino  PR   37.0
# 999             1000        2023-09-05  Candidato_1000  Masculino  RJ   41.0
#
# ...

# %%
print(candidatos_limpo.isnull())
# Out:
#      ID DO CANDIDATO  DATA DA INSCRIÇÃO   NOME   SEXO     UF  IDADE  FORMAÇÃO  \
# 0              False              False  False  False  False  False     False
# 1              False              False  False  False  False   True     False
# 2              False              False  False  False  False  False     False
# 3              False              False  False  False  False  False      True
# 4              False              False  False  False  False  False     False
# ..               ...                ...    ...    ...    ...    ...       ...
# 995            False              False  False  False  False  False     False
# 996            False              False  False   True  False  False     False
# 997            False              False  False   True  False  False     False
# 998            False              False  False  False  False  False     False
# 999            False              False  False  False  False  False     False
#
# ...

# %% [markdown]
# # INDICADOR GERAL
#
# ## Grafico em pizza, de genero.
