# %% [markdown]
# # Analise de cursos de uma Faculadede.

# %%
# !pip isntall matplotlib -q

import pandas as pd
import matplotlib.pyplot as plt

df =pd. read_csv('dados_alunos.csv')

# %%
df.head()
# Out:
#        nome  idade genero        curso  semestre  nota_final  faltas
# 0  Fernanda     22      F   Engenharia         7        8.85      21
# 1   Eduardo     28      M          ADS         1        6.49       9
# 2      Igor     24      M  Arquitetura         3        5.85       8
# 3      Igor     29      F  Arquitetura        10        5.65       7
# 4     Bruno     28      M  Arquitetura         7        8.64       5

# %%
df.tail()
# Out:
#       nome  idade genero       curso  semestre  nota_final  faltas
# 95  Helena     26      M         ADS         2        6.65      21
# 96  Carlos     20      F  Engenharia         8        9.33      24
# 97   Diana     27      M     Direito         1        9.31      17
# 98    Igor     27      F    Medicina         9        8.88      17
# 99  Carlos     22      F    Medicina         8        9.75      21

# %%
df.shape
# Out:
# (100, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nome        100 non-null    object
#  1   idade       100 non-null    int64
#  2   genero      100 non-null    object
#  3   curso       100 non-null    object
#  4   semestre    100 non-null    int64
#  5   nota_final  100 non-null    float64
#  6   faltas      100 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.6+ KB

# %%
df.describe()
# Out:
#             idade    semestre  nota_final      faltas
# count  100.000000  100.000000  100.000000  100.000000
# mean    26.130000    5.880000    7.546800   15.000000
# std      4.871386    2.985757    1.547776    9.222283
# min     18.000000    1.000000    5.000000    0.000000
# 25%     22.000000    3.000000    6.060000    7.000000
# 50%     26.000000    6.000000    7.980000   14.000000
# 75%     30.000000    8.000000    8.872500   24.000000
# max     35.000000   10.000000    9.980000   30.000000

# %%
df.describe(include='object')
# Out:
#          nome genero curso
# count     100    100   100
# unique     10      2     5
# top     Diana      F   ADS
# freq       16     64    26

# %%
df['nome'].value_counts()
# Out:
# nome
# Diana       16
# Helena      16
# Igor        14
# Carlos      10
# Juliana      9
# Bruno        9
# Eduardo      8
# Ana          7
# Gustavo      6
# Fernanda     5
# Name: count, dtype: int64

# %%
contagem_nomes = df['nome'].value_counts()

plt.bar(contagem_nomes.index , contagem_nomes.values, label='Quantidade', color='#35f2a4')
plt.xticks(rotation=45, ha='right')
plt.title('Grafico de Alunos')
plt.xlabel('Nomes')
plt.ylabel('Quantidades')
plt.tight_layout()
plt.legend()
plt.show()

# %%
contagem_genero = df['genero'].value_counts()

plt.bar(contagem_genero.index,contagem_genero.values, color='#2824b3', label='Alunos')
plt.title('Grafico de Alunos(Genero)')
plt.xlabel('Gêneros')
plt.ylabel('Quantidades')
plt.tight_layout()
plt.legend()
plt.show()

# %%
contagem_cursos = df['curso'].value_counts()

plt.bar(contagem_cursos.index,contagem_cursos.values, label='Alunos', color='#618dd4')
plt.title('Grafico de Alunos(Cursos)')
plt.xlabel('Cursos')
plt.ylabel('Quantidades')
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# # Nota media por curso

# %%
nota_media_por_curso = df.groupby('curso')['nota_final'].mean().sort_values(ascending=False)

plt.plot(nota_media_por_curso)
plt.title('Grafico Media por Cursos')
plt.xlabel('Cursos')
plt.ylabel('Nota media')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# C:\Users\Aluno Tarde\AppData\Local\Temp\ipykernel_6680\3142189674.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Quantidade de Aluno homens e mulheres por curso

# %%
quantidades_de_aluno = df.groupby(['curso','genero']).size().unstack(fill_value=0)

plt.plot(quantidades_de_aluno)
plt.title('Grafico por Cursos(M,F)')
plt.xlabel('Cursos')
plt.ylabel('Nota media')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# C:\Users\Aluno Tarde\AppData\Local\Temp\ipykernel_6680\3746431976.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Nota  media dos homens das mulheres

# %%
notamdeia_genero = df.groupby('genero')['nota_final'].mean()

plt.bar(notamdeia_genero.index, notamdeia_genero.values)
plt.title('Grafico Media de Notas(M,F)')
plt.xlabel('Alunos')
plt.ylabel('Nota media')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# C:\Users\Aluno Tarde\AppData\Local\Temp\ipykernel_6680\776428750.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Media de semestre por cursos

# %%
media_semestrecursos = df.groupby(['curso', 'semestre'])['nota_final'].mean().unstack()

plt.bar(media_semestrecursos.index, media_semestrecursos.values, color='mediumseagreen')
plt.title('Idade Média por Curso')
plt.xlabel('Curso')
plt.ylabel('Idade Média')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[139], line 3
#       1 media_semestrecursos = df.groupby(['curso', 'semestre'])['nota_final'].mean().unstack()
# ----> 3 plt.bar(media_semestrecursos.index, media_semestrecursos.values, color='mediumseagreen')
#       4 plt.title('Idade Média por Curso')
#       5 plt.xlabel('Curso')
#
# File c:\Users\Aluno Tarde\Documents\calebe\.venv\Lib\site-packages\matplotlib\pyplot.py:2979, in bar(x, height, width, bottom, align, data, **kwargs)
#    2968 @_copy_docstring_and_deprecators(Axes.bar)
#    2969 def bar(
#    2970     x: float | ArrayLike,
#    (...)   2977     **kwargs,
#    2978 ) -> BarContainer:
# -> 2979     return gca().bar(
#    2980         x,
#    2981         height,
#    2982         width=width,
#    2983         bottom=bottom,
#    2984         align=align,
#    2985         **({"data": data} if data is not None else {}),
#    2986         **kwargs,
#    2987     )
#
# File c:\Users\Aluno Tarde\Documents\calebe\.venv\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Aluno Tarde\Documents\calebe\.venv\Lib\site-packages\matplotlib\axes\_axes.py:2583, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2580     if yerr is not None:
#    2581         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2583 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2584     # Make args iterable too.
#    2585     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2587 # Now that units have been converted, set the tick locations.
#    2588 if orientation == 'vertical':
#
# File c:\Users\Aluno Tarde\Documents\calebe\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:544, in broadcast_arrays(subok, *args)
#     537 # nditer is not used here to avoid the limit of 32 arrays.
#     538 # Otherwise, something like the following one-liner would suffice:
#     539 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     540 #                  order='C').itviews
#     542 args = [np.array(_m, copy=None, subok=subok) for _m in args]
# --> 544 shape = _broadcast_shape(*args)
#     546 result = [array if array.shape == shape
#     547           else _broadcast_to(array, shape, subok=subok, readonly=False)
#     548                           for array in args]
#     549 return tuple(result)
#
# File c:\Users\Aluno Tarde\Documents\calebe\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:419, in _broadcast_shape(*args)
#     414 """Returns the shape of the arrays that would result from broadcasting the
#     415 supplied arrays against each other.
#     416 """
#     417 # use the old-iterator because np.nditer does not handle size 0 arrays
#     418 # consistently
# --> 419 b = np.broadcast(*args[:32])
#     420 # unfortunately, it cannot handle 32 or more arguments directly
#     421 for pos in range(32, len(args), 31):
#     422     # ironically, np.broadcast does not properly handle np.broadcast
#     423     # objects (it treats them as scalars)
#     424     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (5,) and arg 1 with shape (5, 10).

# %% [markdown]
# # Idade media por curso

# %%
idade_mediacurso = df.groupby('curso')['idade'].mean().sort_values(ascending=False)
display(idade_mediacurso)
# Out:
# curso
# Medicina       27.187500
# Arquitetura    26.700000
# ADS            26.384615
# Engenharia     26.045455
# Direito        24.062500
# Name: idade, dtype: float64

# %%
plt.bar(idade_mediacurso.index,idade_mediacurso.values)
plt.title('Idade Media por Cursos')
plt.xlabel('Cursos')
plt.ylabel('Nota media')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# C:\Users\Aluno Tarde\AppData\Local\Temp\ipykernel_6680\2994581296.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Media de idade por semestre

# %%
media_idade_semestre = df.groupby('idade')['semestre'].mean().sort_values(ascending=False)
display(media_semestrecursos)
# Out:
# semestre           1      2      3         4         5       6         7   \
# curso
# ADS          7.213333  7.855  9.045  9.270000  7.625000  7.3175  6.396667
# Arquitetura  6.303333    NaN  6.520  8.326667  6.710000  9.4400  8.640000
# Direito      8.735000  7.225  6.310  8.630000       NaN     NaN       NaN
# Engenharia   8.520000  6.550  8.050  8.830000  8.433333  5.0500  7.704286
# Medicina     5.780000  8.000    NaN  7.740000       NaN  5.7950  7.150000
#
# semestre           8      9         10
# curso
# ADS          7.085000  5.490  6.967500
# Arquitetura  7.780000  5.610  7.546667
# Direito      8.910000  7.650  8.515000
# Engenharia   8.680000  7.220  7.270000
# Medicina     8.256667  8.465  8.200000

# %%
plt.bar(media_idade_semestre.index,media_idade_semestre.values)
plt.title('Idade Media por Cursos')
plt.xlabel('Cursos')
plt.ylabel('Nota media')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# C:\Users\Aluno Tarde\AppData\Local\Temp\ipykernel_6680\245084626.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
